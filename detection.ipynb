# %%
# !pip install tensorflow numpy pandas matplotlib tqdm seaborn scikit-learn
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.17.0-cp39-cp39-macosx_12_0_arm64.whl (236.1 MB)
#      |████████████████████████████████| 236.1 MB 29.2 MB/s eta 0:00:01███████████████▉| 235.3 MB 29.2 MB/s eta 0:00:01
# Collecting numpy
#   Downloading numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 31.9 MB/s eta 0:00:01
# Collecting pandas
#   Downloading pandas-2.2.3-cp39-cp39-macosx_11_0_arm64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 11.3 MB/s eta 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 15.2 MB/s eta 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 27.0 MB/s eta 0:00:01
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      |████████████████████████████████| 294 kB 27.3 MB/s eta 0:00:01
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.2-cp39-cp39-macosx_12_0_arm64.whl (11.0 MB)
#      |████████████████████████████████| 11.0 MB 16.0 MB/s eta 0:00:01
# Requirement already satisfied: packaging in ./venv/lib/python3.9/site-packages (from tensorflow) (24.1)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Collecting tensorboard<2.18,>=2.17
#   Downloading tensorboard-2.17.1-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 19.4 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.12.0 in ./venv/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Collecting flatbuffers>=24.3.25
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Collecting ml-dtypes<0.5.0,>=0.3.1
#   Downloading ml_dtypes-0.4.1-cp39-cp39-macosx_10_9_universal2.whl (396 kB)
#      |████████████████████████████████| 396 kB 19.1 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in ./venv/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting h5py>=3.10.0
#   Downloading h5py-3.12.1-cp39-cp39-macosx_11_0_arm64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 14.9 MB/s eta 0:00:01
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 17.1 MB/s eta 0:00:01
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.66.2-cp39-cp39-macosx_10_9_universal2.whl (10.8 MB)
#      |████████████████████████████████| 10.8 MB 15.7 MB/s eta 0:00:01
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.25.5-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
#      |████████████████████████████████| 394 kB 15.2 MB/s eta 0:00:01
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 2.9 MB/s  eta 0:00:01
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp39-cp39-macosx_12_0_arm64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 18.0 MB/s eta 0:00:01
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.16.0-cp39-cp39-macosx_11_0_arm64.whl (38 kB)
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
#      |████████████████████████████████| 25.8 MB 24.8 MB/s eta 0:00:01
# Collecting numpy
#   Downloading numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl (14.0 MB)
#      |████████████████████████████████| 14.0 MB 15.5 MB/s eta 0:00:01
# Collecting absl-py>=1.0.0
#   Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 35.2 MB/s eta 0:00:01
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Collecting keras>=3.2.0
#   Downloading keras-3.6.0-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 27.2 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.6.6 in ./venv/lib/python3.9/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#      |████████████████████████████████| 508 kB 51.3 MB/s eta 0:00:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#      |████████████████████████████████| 346 kB 40.5 MB/s eta 0:00:01
# Collecting pillow>=8
#   Downloading pillow-10.4.0-cp39-cp39-macosx_11_0_arm64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 19.7 MB/s eta 0:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl (64 kB)
#      |████████████████████████████████| 64 kB 13.8 MB/s eta 0:00:01
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#      |████████████████████████████████| 104 kB 29.7 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.54.1-cp39-cp39-macosx_11_0_arm64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 18.3 MB/s eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (249 kB)
#      |████████████████████████████████| 249 kB 23.4 MB/s eta 0:00:01
# Collecting scipy>=1.6.0
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#      |████████████████████████████████| 30.3 MB 28.0 MB/s eta 0:00:01
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      |████████████████████████████████| 301 kB 23.2 MB/s eta 0:00:01
# Collecting wheel<1.0,>=0.23.0
#   Downloading wheel-0.44.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 23.0 MB/s eta 0:00:01
# Requirement already satisfied: zipp>=3.1.0 in ./venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Collecting optree
#   Downloading optree-0.13.0-cp39-cp39-macosx_11_0_arm64.whl (296 kB)
#      |████████████████████████████████| 296 kB 20.0 MB/s eta 0:00:01
# Collecting namex
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Collecting rich
#   Downloading rich-13.9.2-py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 19.1 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Using cached certifi-2024.8.30-py3-none-any.whl (167 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp39-cp39-macosx_11_0_arm64.whl (120 kB)
#      |████████████████████████████████| 120 kB 5.5 MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.7-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 56.2 MB/s eta 0:00:01
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.0.4-py3-none-any.whl (227 kB)
#      |████████████████████████████████| 227 kB 45.5 MB/s eta 0:00:01
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in ./venv/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.18,>=2.17->tensorflow) (8.5.0)
# Collecting MarkupSafe>=2.1.1
#   Using cached MarkupSafe-2.1.5-cp39-cp39-macosx_10_9_universal2.whl (18 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.9/site-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 30.2 MB/s eta 0:00:01
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: mdurl, numpy, MarkupSafe, markdown-it-py, wheel, werkzeug, urllib3, tzdata, tensorboard-data-server, rich, pytz, pyparsing, protobuf, pillow, optree, namex, ml-dtypes, markdown, kiwisolver, importlib-resources, idna, h5py, grpcio, fonttools, cycler, contourpy, charset-normalizer, certifi, absl-py, wrapt, threadpoolctl, termcolor, tensorflow-io-gcs-filesystem, tensorboard, scipy, requests, pandas, opt-einsum, matplotlib, libclang, keras, joblib, google-pasta, gast, flatbuffers, astunparse, tqdm, tensorflow, seaborn, scikit-learn
# Successfully installed MarkupSafe-2.1.5 absl-py-2.1.0 astunparse-1.6.3 certifi-2024.8.30 charset-normalizer-3.3.2 contourpy-1.3.0 cycler-0.12.1 flatbuffers-24.3.25 fonttools-4.54.1 gast-0.6.0 google-pasta-0.2.0 grpcio-1.66.2 h5py-3.12.1 idna-3.10 importlib-resources-6.4.5 joblib-1.4.2 keras-3.6.0 kiwisolver-1.4.7 libclang-18.1.1 markdown-3.7 markdown-it-py-3.0.0 matplotlib-3.9.2 mdurl-0.1.2 ml-dtypes-0.4.1 namex-0.0.8 numpy-1.26.4 opt-einsum-3.4.0 optree-0.13.0 pandas-2.2.3 pillow-10.4.0 protobuf-4.25.5 pyparsing-3.1.4 pytz-2024.2 requests-2.32.3 rich-13.9.2 scikit-learn-1.5.2 scipy-1.13.1 seaborn-0.13.2 tensorboard-2.17.1 tensorboard-data-server-0.7.2 tensorflow-2.17.0 tensorflow-io-gcs-filesystem-0.37.1 termcolor-2.4.0 threadpoolctl-3.5.0 tqdm-4.66.5 tzdata-2024.2 urllib3-2.2.3 werkzeug-3.0.4 wheel-0.44.0 wrapt-1.16.0
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/Users/gprem/detect-modern-day-slavery/venv/bin/python3 -m pip install --upgrade pip' command.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import seaborn as sns
from sklearn.metrics import confusion_matrix
from datetime import datetime, timedelta
# Out:
# /Users/gprem/detect-modern-day-slavery/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
